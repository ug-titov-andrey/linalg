# %% [markdown]
# # Системы линейных уравнений. Часть 1

# %% [markdown]
# __1.__ Решите систему уравнений методом Гаусса:
#
# $\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$
#
# **Решение.**
#
# Запишем расширенную матрицу системы.
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 &-1 &  -2 \\
# 2 & 1 & -1 & 1 \\
# 1 &  1 & -3 & 1
# \end{matrix} \right |
# \begin{matrix}
# 0 \\
# -2\\
# 4\\
# \end{matrix}
# \end{pmatrix}$
#
# Умножим первую строу на 2 и вычтем из второй Строки. Из третьей строки вычтум первую строку.
#
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 &-1 &  -2 \\
# 0 & -1 & 1 & 5 \\
# 0 &  0 & -2 & 3
# \end{matrix} \right |
# \begin{matrix}
# 0 \\
# -2\\
# 4\\
# \end{matrix}
# \end{pmatrix}$
#
#
# Ранг расширенной матрицы равен рангу матрицы коэффициентов  и меньше числа переменных. Поэтому система совместна и недоопределена.
#
# $\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0 \\
# -x_{2}+x_{3}+5x_{4}=-2 \\
# -2x_{3}+3x_{4}=4.
# \end{cases}$
#
# Примем $x_4$ за параметр и обозначим как с =>
#
# $\begin{cases}
# x_3=-2 + \frac{3}{2}c\\
#  \\
# x_{2} = \frac{13}{2}c\\ \\
# x_1=-2 - 3c
# \end{cases}$
#
# __2.__ Проверьте на совместность и выясните, сколько решений будет иметь система линейных уравнений:
#
# $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$  $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$ $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$
#
# __Решение.__
#
# - $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$ Составим расширенную матрицу <br> <br>
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1  \\
# 2 & -5 & -3 \\
# 1 &  1 & -1 &
# \end{matrix} \right |
# \begin{matrix}
# 4 \\
# -17\\
# 0\\
# \end{matrix}
# \end{pmatrix}$  <br> <br>
# Поменяем местами 3 и 1 строки <br><br>
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 &  1 & -1  \\
# 2 & -5 & -3 \\
# 3 & -1 & 1
# \end{matrix} \right |
# \begin{matrix}
# 0 \\
# -17\\
# 4\\
# \end{matrix}
# \end{pmatrix}$. <br> <br> Ранг расширенной матрицы равен рангу матрицы коэффициентов <br> <br>  и равен числу переменных =>
# Имеется только одно решение. <br><br>
# - $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$. Составим расширенную матрицу  <br> <br>
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6 \\
# 1 & -2 & 3 \\
# 3 & -6 & 9
# \end{matrix}
# \right | \begin{matrix}
# 1 \\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}.$  Сумму 1 и второй строки вычтем из третьей строки => <br><br>
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6 \\
# 1 & -2 & 3 \\
# 0 & 0 & 0
# \end{matrix}
# \right | \begin{matrix}
# 1 \\
# -2\\
# 6
# \end{matrix}
# \end{pmatrix}.
# $ Ранг расширенной матрицы равен 3, а ранг матрицы коэффициентов равен 2 => система несовместна и решения не имеет.
#
#
# - $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$ <br><br>
# Ранг расширенной матрицы равен 2 и равен рангу матрицы коэффициентов. Независимых переменных три. Поэтому система совместна и недоопределена. => Имеет бесконечное множество решений.
#
# **3.**  Проверьте на совместность и выясните, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей:
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$
#
# Определитель верхнедиагональной матрицы равен произведению элементов главной диагонали. Для данной матрицы определитель равен 30. Определитель расширенной матрицы также не равен нулю. Значит ранг расширенно матрицы равен рангу матрицы коэффициентов и  равен числу независимых переменных => Система совместна и имеет одно решение.
#
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей:
#
# $\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$
#
# Найдите соотношение между параметрами $a$, $b$ и $c$, при которых система считается несовместной.
#
# После проведения линейных операций над строками, не меняющими ранг матрицы, можно получить матрицу:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4a\\
# c - 7a -2(b-4a)
# \end{matrix}
# \end{pmatrix}.$
#
# Ранг матрицы коэффициетов равен 2. Для того, чтобы ранг расширенной матрицы тоже был равен 2,
# должно выполняться равенство: <br> c - 7a -2(b-4a)=0 => c+a-2b = 0,  что и является решением задачи.

# %% [markdown]
# # Системы линейных уравнений. Часть 2

# %% [markdown]
# __1.__ Решите систему уравнений методом Крамера:
#
# $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$;  $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
#
# __Решение.__
#
# * Ранг расширенной матрицы совпадает с рангом расширенной матрицы и равен числу переменных. <br><br>
# $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$ <br> <br>
# Найдем определитель матрицы коэффициентов:
# $detA = \begin{vmatrix}
# 1 & -2 \\
# 3 & -4
# \end{vmatrix} = -4 + 6 = 2 $ <br> <br>
# Найден определители матриц,  получаемых заменой  𝑖 -го столбца на вектор-столбец свободных членов  𝑏. <br> <br>
# $detA_1 = \begin{vmatrix}
# 1 & -2 \\
# 7 & -4
# \end{vmatrix} = -4 + 14 = 10 $ <br><br>
# $detA_1 = \begin{vmatrix}
# 1 & 1 \\
# 3 & 7
# \end{vmatrix} = 7 - 3 = 4 $ <br><br>
# Тогда $x_1 =  \frac{10}{2} =5 $, $x_2=   \frac{4}{2}=2 $ <br><br>
# * $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$ <br><br>
# $detA = \begin{vmatrix}
# 2 & -1 & 5 \\
# 1 & 1 & -3 \\
# 2 & 4 & 1
# \end{vmatrix} = 2 \begin{vmatrix}
# 1 & -3 \\
# 4 & 1
# \end{vmatrix}  + (-1 \cdot{}-1) \begin{vmatrix}
# 1 & -3 \\
# 2 & 1
# \end{vmatrix} +  5 \begin{vmatrix}
# 1 & 1 \\
# 2 & 4
# \end{vmatrix}$ = 2(1+12) + (1+6) + 5(4-2) = 43 <br><br>
# $detA_1 = \begin{vmatrix}
# 10 & -1 & 5 \\
# -2 & 1 & -3 \\
# 1 & 4 & 1
# \end{vmatrix} = 10 \begin{vmatrix}
# 1 & -3 \\
# 4 & 1
# \end{vmatrix}  + (-1 \cdot{}-1) \begin{vmatrix}
# -2 & -3 \\
# 1 & 1
# \end{vmatrix} +  5 \begin{vmatrix}
# -2 & 1 \\
# 1 & 4
# \end{vmatrix}$ =86 <br><br>
# $detA_2 = \begin{vmatrix}
# 2 & 10 & 5 \\
# 1 & -2 & -3 \\
# 2 & 1 & 1
# \end{vmatrix} =-43 $ <br><br>
# $detA_3 = \begin{vmatrix}
# 2 & -1& 10 \\
# 1 & 1 & -2 \\
# 2 & 4 & 1
# \end{vmatrix} =43 $ <br><br>
# Тогда $x_1 =  \frac{86}{43} =2 $, $x_2=   \frac{-43}{43}=-1 $   $x_3=   \frac{43}{43}=1$ <br><br>
#
# __2*.__ Найдите $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#  $\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$;  $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$
#
#
# * Решение <br><br>
# $\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$  <br><br>
# Умножим последовательно 1 строку матрицы коэффициентов на 2 и 3, а затем вычтем их из 2 и 3 строки соответственно => получим <br><br>
# $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 20 & 22
# \end{pmatrix}$ <br><br> Матрица L на этом этапе равна
# $\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & l_{32} & 1
# \end{pmatrix}$ <br><br>
# Умножим вторую строку преобразованной матрицы коэффициентов на 4 и вычтем из 3 строки => <br><br>
#
#  $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 6
# \end{pmatrix}$. <br><br>
# Значит L=$\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & 4 & 1
# \end{pmatrix}$,  U =  $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 6
# \end{pmatrix}$. <br><br>
# *  $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$ <br><br>
# Производя операции, аналогичные предыдущему случаю, можно получить: <br> <br>
# L =  $\begin{pmatrix}
# 1 & 0 & 0 & 0 \\
# 2 & 1 & 0 & 0 \\
# 3 & 5 & 1 & 0 \\
# 4 & 6 & 7 & 1
# \end{pmatrix}$; U=$\begin{pmatrix}
# 1 & 1 & 2 & 4 \\
# 0 & 3 & 4 & 1 \\
# 0 & 0 & 3 & 1 \\
# 0 & 0 & 0 & 4
# \end{pmatrix}$

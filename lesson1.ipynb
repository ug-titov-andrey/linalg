# %% [markdown]
# # Линейное пространство. Основные понятия.

# %% [markdown]
# **1.** Исследуйте на линейную зависимость:
#
# $$f_1(x)=e^x, f_2(x)=1, f_3(x)=x+1, f_4(x)=x-e^{x}.$$
#
# **Решение**
#
# $e^x=x+1-(x-e^x)-1$. <br>
# **Один из векторов является линейной комбинацией трех остальных. Из этого следует, что векторы линейно зависимы.**
#
# **2.** Исследуйте на линейную зависимость:
# $$f_1(x)=2, f_2(x)=x, f_3(x)=x^{2}, f_4(x)=(x+1)^2$$
#
# **Решение**
#
# $f_4(x)=(x+1)^2=x^2+2x+1$.
# Тогда $x^2+2x+1=\frac{2}{2}+2*2+x^2$.
#
# То есть $f_4(x)=\frac{1}{2}f_1(x)+2f_2(x)+f_3(x)$.
#
# **Один из векторов является линейной комбинацией трех остальных. Из этого следует, что векторы линейно зависимы.**
#
# **3.** Найдите координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.
#
# **Решение**
#
# В стандартном базисе линейного пространства  можно записать:
#
# $𝑥=(2,3,5)=(2,0,0)+(0,3,0)+(0,0,5)=1\cdot(2,0,0)+3\cdot(0,1,0)+\frac{1}{2}\cdot(0,0,10)=1b_2+3b_3+\frac{1}{2}b_1$
#
# **Координаты вектора  𝑥  в новом базисе базисе —  (1/2 ,  1 ,  3).**
#
# **4.** Найдите координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# 1. в базисе $1$, $x$, $x^{2}$;
#
# 2. в базисе $x^{2}$, $x-1$, $1$.
#
# **Решение**
#
# 1. Обозначим базисные векторы, как $b_1=1$, $b_2=x$, $b_3=x^2$.  =><br> => $3x^{2}-2x+2 = 3b_3-2b_2+2b_1$.
# **В принятых выше обозначениях исходный вектор имеет координаты (2, -2, 3)**
#
# 2. Обозначим базисные векторы, как $b_1=x^2$, $b_2=x-1$, $b_3=1$.  =><br> => $3x^{2}-2x+2 = 3x^2-2(x-1)+0=3b_1-2b_2+0b_3$.
# **В принятых выше обозначениях исходный вектор имеет координаты (3, 2, 0)**
#
# **5.** Установите, считается ли линейным подпространством:
#
# 1. Совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
# 2. Все векторы, считающиеся линейными комбинациями данных векторов $\{u_{1}, u_{2} \ldots, u_{n}\}$.
#
# **Решение**
#
# Для того, чтобы множество  векторов считалось линейным пространством, оно должно удовлетворять двум аксиомам: сумма любых двух векторов должнен принадлежать множеству; при умножении любого вектора множества на константу, полученный вектор также принадлежит анализируемому множеству.
# 1. возьмем любые два вектора с нулевой первой координатой: $(0,a,b)$ и $(0,d,c)$. Тогда $(0,a,b)+(0,d,c) = (0,a+d,b+c)$. Для суммы любых двух векторов с нулевой первой компонентой, полученный суммарный вектор также имеет нулевую первую компоненту. <br> Проверка второй аксиомы: $\lambda\cdot(0,a,b) = (0,\lambda\cdot a, \lambda\cdot b) $. <br>**Обе аксиомы выполняются, а значит  совокупность всех векторов трёхмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю, является линейным пространством.**
# <br>
# 2.Сумма любых двух векторов является их линейной комбинацией. Таким образо, первая аксиома удовлетворяется.  Если линейную комбинацию некоторых векторов умножить на число, мы получим линейную комбинацию этих же векторов с коэффициентами, умноженными на это число. Значит вторая аксиома также удовлетворяется. <br> **Обе аксиомы удовлетворяются. Поэтому, все векторы, считающиеся линейными комбинациями данных векторов $\{u_{1}, u_{2} \ldots, u_{n}\}$ являются линейным пространством.**

# %% [markdown]
# # Линейное пространство. Основные понятия. Часть 2

# %% [markdown]
# **1.** Найдите скалярное произведение векторов 𝑥,𝑦 $\in \mathbb{ℝ}$ : а) 𝑥=(0,−3,6), 𝑦=(−4,7,9); б) 𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2).
#
# **Решение**
#
# В ортонормированном базисе скалярное произведение определяется суммой произведений соответсвующих координат:
#
# a)
# $\overrightarrow{x}\cdot{}\overrightarrow{y}=x_1y_1 + x_2y_2+x_3y_3=0-21+54 =33$
#
# б)
# $\overrightarrow{x}\cdot{}\overrightarrow{y}=x_1y_1 + x_2y_2+x_3y_3+x_4y_4=-21-4+0+2 =-23$
#
# ниже приведена реализация на python

# %%
import numpy as np
print(f'для варианта а) скалярное произведение равно => {np.array([0,-3,6]).dot(np.array([-4,7,9]))}')
print(f'для варианта б) скалярное произведение равно => {np.array([7,-4,0,1]).dot(np.array([-3,1,11,2]))}')
# Out:
# для варианта а) скалярное произведение равно => 33
# для варианта б) скалярное произведение равно => -23

# %% [markdown]
# **2.**  Найдите нормы векторов  x(4,2,4)  и  y(12,3,4)  и угол между ними.
#
# **Решение**
#
# Для пространтства $\mathbb{R}^3$ евклидова норма вектора   $\overrightarrow{x}$определяется выражением: $\|\overrightarrow{x}\|=\sqrt{x_1^2+x_2^2+x_3^2}$. <br>
# Тогда евклидова норма первого вектора равна  $\|\overrightarrow{x(x_1,x_2, x_3)}\|=\sqrt{16+4+16}=6$ <br>
# Евклидова норма второго вектора равна $\|\overrightarrow{y(y_1,y_2, y_3)}\|=\sqrt{144+9+16}=\sqrt{169}=13$
#
# угол между векторами равен x и равен <br>
# $\varphi = acos(\frac{(x,y)}{\left \|x\right \|\cdot\left \|y\right \|})=acos(\frac{4*12+2*3+4*4}{6*13})\approx{26.2}^0$.
# Ниже приведен код решения задачи на python

# %%
import math
from numpy.linalg import norm
x = np.array([4,2,4])
y = np.array([12,3,4]) 
norm_x = norm(x)
norm_y = norm(y)
print(f'Норма первого вектора равна => {norm_x}')
print(f'Норма второго вектора равна => {norm_y}')
print(f'угол между векторами равен => {math.degrees(math.acos(x.dot(y)/(norm_x*norm_y)))} ')
x.dot(y)/(norm_x*norm_y)
# Out:
# Норма первого вектора равна => 6.0
# Норма второго вектора равна => 13.0
# угол между векторами равен => 26.176952171666542
# 0.8974358974358975

# %% [markdown]
# **3.** Определите, будет ли линейное пространство евклидовым, если за скалярное произведение принять:
#
# 1. Произведение длин векторов;
# 2. Утроенное обычное скалярное произведение векторов?
#
# **Решение**
#
#
# Линейно евклидово пространство должно удовлетворять 4 аксиомам:
# 1) $(x,y)=(y,x).$<br>
# 2) $(\lambda x, y)=\lambda(x, y).$<br>
# 3) $(x_{1}+x_{2},y)=(x_{1},y)+(x_{2},y).$<br>
# 4) $(x, x)\geq0$, причём $(x,x)=0\Leftrightarrow x=0.$
#
# При проверке каждой из определенных операций скалярного умножения на удовлетворения 4 аксиомам, введем три произвольных вектора:
#
# $x(x_1,x_2,x_3)$, $y(y_1,y_2,y_3)$, $z(z_1,z_2,z_3)$
#
#
# 1.  Скалярное произведение равно  произведению длин векторов.
# Проверим норму для аксиомы 3. <br>
# $(x+y,z) = \sqrt{(x_1+y_1)^2+(x_2+y_2)^2+(x_3+y_3)^2}\cdot{}\sqrt{z_1^2+z_2^2+z_3^2}$ <br>
# #### Очевидно, что $(x+y,z)\neq(x,z)+(y,z).$ Таким образом, пространство не линейно евклидово.<br>
# 2. Скалярное произведение равно утроенному обычному скалярному произведению векторов? <br>
# Аксиома 1. $(x,y)=3\cdot(x_1\cdot{}y_1+x_2\cdot{}y_2+x_3\cdot{}y_3) = 3\cdot(y_1\cdot{}x_1+y_2\cdot{}x_2+y_3\cdot{}x_3)=(y,x) $ <br> Аксиома 2. $(\lambda x,y)=3\cdot(\lambda(x_1)\cdot{}y_1+\lambda(x_2)\cdot{}y_2+\lambda(x_3)\cdot{}y_3) = 3\lambda\cdot(x_1\cdot{}y_1+x_2\cdot{}y_2+x_3\cdot{}y_3)=3\lambda(x, y)$.<br>
# Аксиома 3. $(x+y,z)=3((x_1+y_1)z_1+(x_2+y_2)z_2+(x_3+y_3)z_3) = 3(x_1 z_1+x_2 z_2+x_3 z_3)=3(y_1 z_1+y_2 z_2+y_3 z_3)= (x,z)+(y,z)$ <br>
# Аксиома 4. $(x, x) = 3(x_1x_1+x_2x_2+x_3x_3)\geq0$, причём $(x,x)=0\Leftrightarrow x=0.$ <br>
# #### Таким образом, все четыре аксиомы выполняются и такое пространсто является линейно евклидовым.

# %% [markdown]
# **4.** Выясните, какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве  ℝ3 :
# $\mathbb{R}^{3}$:<br>
# 1. $(1,0,0),(0,0,1);$ <br>
# 2. $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# 3. $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# 4. $(1,0,0),(0,1,0),(0,0,1)$
#
# ***Решение***
#
# 1. **В трехмерном пространстве 3 базисных вектора. Поэтому два выектора  $(1,0,0)$ и $(0,0,1)$ не могут образовывать  базис.**
# 2. $ e_1 = (1/\sqrt{2},-1/\sqrt{2},0)$, $e_2 = (1/\sqrt{2},1/\sqrt{2},0)$, $e_3-(0,0,1)$
# * Все три вектора линейно-независимы
# * $\|e_1\|=1, \|e_2\|=1, \|e_3\|=1$
# * $(e_1,e_2)=(e_1,e_3)=(e_2,e_3)=0$ <br>
#  **Данные три вектора образуют ортонормированный базис.**
# 3. $e_1=(1/2, -1/2, 0), e_2=(0, 1/2, 1/2), e_3 (0,0,1)$.<br>
# $(e_1,e_2)=-1/4$
# $(e_2,e_31)=1/2$.<br>
# **Так как взаимные скалярные умножения не равны нулю, то вектора не ортогональны. Значит базис не ортонормированны.** <br><br>
# 4. $ e_1=(1,0,0),e_2=(0,1,0),e_3=(0,0,1)$
# * Все три вектора линейно-независимы
# * $\|e_1\|=1, \|e_2\|=1, \|e_3\|=1$
# * $(e_1,e_2)=(e_1,e_3)=(e_2,e_3)=0$ <br>
#
# **Данные три вектора образуют ортонормированный базис**
